# %%
import sys
import os
import json

# %%
def load_json(data_file):
    if os.path.isfile(data_file):
        with open(data_file, 'r') as read_file:
            data = json.load(read_file)
            return data

def load_list_file(list_file):
    with open(list_file, 'r') as read_file:
        dialog_id_list = read_file.readlines()
        dialog_id_list = [l.strip('\n') for l in dialog_id_list]
        return dialog_id_list
    return

# %%
dialog_data_file = './MultiWOZ/data.json'
dialog_data = load_json(dialog_data_file)
dialog_id_list = list(set(dialog_data.keys())) # Bug: v1.0 contains duplicate id in the valid data
print('# of dialogs:', len(dialog_data))
# print(dialog_data['PMUL4641.json']) # print a sample dialog
# Out:
# # of dialogs: 9855

# %%
valid_list_file = './MultiWOZ/valListFile.json'
test_list_file = './MultiWOZ/testListFile.json'

valid_id_list = list(set(load_list_file(valid_list_file))) # Bug: v1.0 contains duplicate id in the valid data
test_id_list = load_list_file(test_list_file)
train_id_list = [did for did in dialog_id_list if did not in (valid_id_list + test_id_list)]
print('# of train dialogs:', len(train_id_list))
print('# of valid dialogs:', len(valid_id_list))
print('# of test dialogs :', len(test_id_list))
assert(len(dialog_id_list) == len(train_id_list) + len(valid_id_list) + len(test_id_list))
# Out:
# # of train dialogs: 7953
# # of valid dialogs: 902
# # of test dialogs : 1000

# %%
train_data = [v for k, v in dialog_data.items() if k in train_id_list]
valid_data = [v for k, v in dialog_data.items() if k in valid_id_list]
test_data = [v for k, v in dialog_data.items() if k in test_id_list]
assert(len(train_data) == len(train_id_list))
assert(len(valid_data) == len(valid_id_list))
assert(len(test_data) == len(test_id_list))

# %%
train_data[0]
# Out:
# {'goal': {'attraction': {},
#   'eod': True,
#   'hospital': {},
#   'hotel': {'book': {'day': 'tuesday',
#     'invalid': False,
#     'people': '6',
#     'pre_invalid': True,
#     'stay': '2'},
#    'fail_book': {'stay': '3'},
#    'fail_info': {},
#    'info': {'internet': 'yes',
#     'parking': 'yes',
#     'pricerange': 'cheap',
#     'type': 'hotel'}},
#   'message': ["You are looking for a <span class='emphasis'>place to stay</span>. The hotel should be in the <span class='emphasis'>cheap</span> price range and should be in the type of <span class='emphasis'>hotel</span>",
#    "The hotel should <span class='emphasis'>include free parking</span> and should <span class='emphasis'>include free wifi</span>",
#    "Once you find the <span class='emphasis'>hotel</span> you want to book it for <span class='emphasis'>6 people</span> and <span class='emphasis'>3 nights</span> starting from <span class='emphasis'>tuesday</span>",
#    "If the booking fails how about <span class='emphasis'>2 nights</span>",
#    "Make sure you get the <span class='emphasis'>reference number</span>"],
#   'messageLen': 6,
#   'police': {},
#   'restaurant': {},
#   'taxi': {},
#   'topic': {'attraction': False,
#    'booking': False,
#    'general': False,
#    'hospital': False,
#    'hotel': False,
#    'police': False,
#    'restaurant': False,
#    'taxi': False,
#    'train': False},
#   'train': {}},
#  'log': [{'metadata': {},
#    'text': 'am looking for a place to to stay that has cheap price range it should be in a type of hotel'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'not mentioned',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Okay, do you have a specific area you want to stay in?'},
#   {'metadata': {},
#    'text': "no, i just need to make sure it's cheap. oh, and i need parking"},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [], 'day': '', 'people': '', 'stay': ''},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'I found 1 cheap hotel for you that includes parking. Do you like me to book it?'},
#   {'metadata': {},
#    'text': 'Yes, please. 6 people 3 nights starting on tuesday.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '3'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': "I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?"},
#   {'metadata': {}, 'text': 'how about only 2 nights.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Booking was successful.\nReference number is : 7GAWK763. Anything else I can do for you?'},
#   {'metadata': {}, 'text': 'No, that will be all. Good bye.'},
#   {'metadata': {'attraction': {'book': {'booked': []},
#      'semi': {'area': '', 'name': '', 'type': ''}},
#     'hospital': {'book': {'booked': []}, 'semi': {'department': ''}},
#     'hotel': {'book': {'booked': [{'name': 'the cambridge belfry',
#         'reference': '7GAWK763'}],
#       'day': 'tuesday',
#       'people': '6',
#       'stay': '2'},
#      'semi': {'area': 'not mentioned',
#       'internet': 'not mentioned',
#       'name': 'not mentioned',
#       'parking': 'yes',
#       'pricerange': 'cheap',
#       'stars': 'not mentioned',
#       'type': 'hotel'}},
#     'police': {'book': {'booked': []}, 'semi': {}},
#     'restaurant': {'book': {'booked': [], 'day': '', 'people': '', 'time': ''},
#      'semi': {'area': '', 'food': '', 'name': '', 'pricerange': ''}},
#     'taxi': {'book': {'booked': []},
#      'semi': {'arriveBy': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}},
#     'train': {'book': {'booked': [], 'people': ''},
#      'semi': {'arriveBy': '',
#       'day': '',
#       'departure': '',
#       'destination': '',
#       'leaveAt': ''}}},
#    'text': 'Thank you for using our services.'}]}

# %%
def get_dst_diff(prev_d, crnt_d):
    assert len(prev_d) == len(crnt_d)
    diff = {}
    for ((k1, v1), (k2, v2)) in zip(prev_d.items(), crnt_d.items()):
        assert k1 == k2
        if v1 != v2: # updated
            diff[k2] = v2
    return diff

def analyze_dialog(d, print_dialog=True):
    assert 'log' in d
    assert 'goal' in d
    domains = []
    ignore_keys_in_goal = ['eod', 'messageLen', 'message'] # eod (probably) means the user archieved the goal. 
    for dom_k, dom_v  in d['goal'].items():
        if dom_v and dom_k not in ignore_keys_in_goal: # check whether contains some goal entities
            domains.append(dom_k)
    print('{} domain(s): {}'.format(len(domains), domains))
    
    if print_dialog:
        prev_d = None
        for i, t in enumerate(d['log']):
            spk = 'Usr' if i % 2 == 0 else 'Sys' # Turn 0 is always a user's turn in this corpus.
            if spk == 'Sys':
                if prev_d is None:
                    prev_d = t['metadata']
                else:
                    crnt_d = t['metadata']
                    dst_diff = get_dst_diff(prev_d, crnt_d)
                    print('Updated DST:', dst_diff)
                    prev_d = crnt_d
            u = t['text']
            print('{}: {}'.format(spk, u))

for d in train_data[:3]:
    print('-' * 50)
    analyze_dialog(d, True)
# Out:
# --------------------------------------------------
# 2 domain(s): ['hotel', 'topic']
# Usr: am looking for a place to to stay that has cheap price range it should be in a type of hotel
# Sys: Okay, do you have a specific area you want to stay in?
# Usr: no, i just need to make sure it's cheap. oh, and i need parking
# Updated DST: {'hotel': {'book': {'booked': [], 'stay': '', 'day': '', 'people': ''}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: I found 1 cheap hotel for you that includes parking. Do you like me to book it?
# Usr: Yes, please. 6 people 3 nights starting on tuesday.
# Updated DST: {'hotel': {'book': {'booked': [], 'stay': '3', 'day': 'tuesday', 'people': '6'}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: I am sorry but I wasn't able to book that for you for Tuesday. Is there another day you would like to stay or perhaps a shorter stay?
# Usr: how about only 2 nights.
# Updated DST: {'hotel': {'book': {'booked': [{'name': 'the cambridge belfry', 'reference': '7GAWK763'}], 'stay': '2', 'day': 'tuesday', 'people': '6'}, 'semi': {'name': 'not mentioned', 'area': 'not mentioned', 'parking': 'yes', 'pricerange': 'cheap', 'stars': 'not mentioned', 'internet': 'not mentioned', 'type': 'hotel'}}}
# Sys: Booking was successful.
# Reference number is : 7GAWK763. Anything else I can do for you?
# Usr: No, that will be all. Good bye.
# Updated DST: {}
# Sys: Thank you for using our services.
# --------------------------------------------------
# 1 domain(s): ['police']
# Usr: Hello, I have been robbed.  Can you please help me get in touch with the police?
# Sys: Parkside Police Station is in Parkside, Cambridge. Their number is 01223358966. Anything else I can do for you?
# Usr: Can I please have the postcode as well?
# Updated DST: {}
# Sys: The postcode for the Parkside Police Station is CB11JG. Can I help you with anything else?
# Usr: Was Parkside the address of the police station? If not, can I have the address please?
# Updated DST: {}
# Sys: Yes, Parkside is the address.
# Usr: Thank you that will be all for now.
# Updated DST: {}
# Sys: Great. Thank you for contacting Cambridge Towninfo Centre.
# Usr: You were great. Goodbye.
# Updated DST: {}
# Sys: We are happy to help. Have a good day!
# --------------------------------------------------
# 4 domain(s): ['bus', 'hotel', 'topic', 'train']
# Usr: I need to book a hotel in the east that has 4 stars.
# Sys: I can help you with that. What is your price range?
# Usr: That doesn't matter as long as it has free wifi and parking.
# Updated DST: {'hotel': {'book': {'booked': [], 'people': '', 'day': '', 'stay': ''}, 'semi': {'name': 'not mentioned', 'area': 'east', 'parking': 'yes', 'pricerange': 'not mentioned', 'stars': '4', 'internet': 'yes', 'type': 'not mentioned'}}}
# Sys: If you'd like something cheap, I recommend the Allenbell. For something moderately priced, I would recommend the Warkworth House.
# Usr: Could you book the Wartworth for one night, 1 person?
# Updated DST: {}
# Sys: What day will you be staying?
# Usr: Friday and Can you book it for me and get a reference number ?
# Updated DST: {'hotel': {'book': {'booked': [{'name': 'warkworth house', 'reference': 'BMUKPTG6'}], 'people': '1', 'day': 'friday', 'stay': '1'}, 'semi': {'name': 'not mentioned', 'area': 'east', 'parking': 'yes', 'pricerange': 'not mentioned', 'stars': '4', 'internet': 'yes', 'type': 'not mentioned'}}}
# Sys: Booking was successful.
# Reference number is : BMUKPTG6.  Can I help you with anything else today?
# Usr: I am looking to book a train that is leaving from Cambridge to Bishops Stortford on Friday.
# Updated DST: {'train': {'book': {'booked': [], 'people': ''}, 'semi': {'leaveAt': 'not mentioned', 'destination': 'bishops stortford', 'day': 'friday', 'arriveBy': 'not mentioned', 'departure': 'cambridge'}}}
# Sys: There are a number of trains leaving throughout the day.  What time would you like to travel?
# Usr: I want to get there by 19:45 at the latest.
# Updated DST: {'train': {'book': {'booked': [], 'people': ''}, 'semi': {'leaveAt': 'not mentioned', 'destination': 'bishops stortford', 'day': 'friday', 'arriveBy': '19:45', 'departure': 'cambridge'}}}
# Sys: Okay! The latest train you can take leaves at 17:29, and arrives by 18:07. Would you like for me to book that for you?
# Usr: Yes please. I also need the travel time, departure time, and price.
# Updated DST: {'train': {'book': {'booked': [{'trainID': 'TR1567', 'reference': 'UIFV8FAS'}], 'people': '1'}, 'semi': {'leaveAt': 'not mentioned', 'destination': 'bishops stortford', 'day': 'friday', 'arriveBy': '19:45', 'departure': 'cambridge'}}}
# Sys: Reference number is : UIFV8FAS. The price is 10.1 GBP and the trip will take about 38 minutes. May I be of any other assistance?
# Usr: Yes. Sorry, but suddenly my plans changed. Can you change the Wartworth booking to Monday for 3 people and 4 nights?
# Updated DST: {'hotel': {'book': {'booked': [{'name': 'warkworth house', 'reference': 'YF86GE4J'}], 'people': '3', 'day': 'monday', 'stay': '4'}, 'semi': {'name': 'not mentioned', 'area': 'east', 'parking': 'yes', 'pricerange': 'not mentioned', 'stars': '4', 'internet': 'yes', 'type': 'not mentioned'}}}
# Sys: I have made that change and your reference number is YF86GE4J
# Usr: Thank you very much, goodbye.
# Updated DST: {}
# Sys: You're welcome. Have a nice day!

# %% [markdown]
# ## DB

# %%
hotel_db_list = load_json('./MultiWOZ/hotel_db.json')
train_db_list = load_json('./MultiWOZ/train_db.json')
attractin_db_list = load_json('./MultiWOZ/attraction_db.json')
restaurant_db_list = load_json('./MultiWOZ/restaurant_db.json')
print(hotel_db_list[0]) # print a sample entity
# Out:
# {'address': '124 tenison road', 'area': 'east', 'internet': 'yes', 'parking': 'no', 'id': '0', 'location': [52.1963733, 0.1987426], 'name': 'a and b guest house', 'phone': '01223315702', 'postcode': 'cb12dp', 'price': {'double': '70', 'family': '90', 'single': '50'}, 'pricerange': 'moderate', 'stars': '4', 'takesbookings': 'yes', 'type': 'guesthouse'}
